# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class linked_list:
    def __init__(self):
        self.head = None
        
    def append(self,data):
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            return
        lastnode = self.head
        while lastnode.next:
            lastnode = lastnode.next
        lastnode.next = newnode
      
        
    def printlist(self):
        currentnode = self.head
        while currentnode:
            print(currentnode.data)
            currentnode = currentnode.next
            
    def insert(self,position,data):
        newnode = Node(data)
        if position == 0:
            newnode.next = self.head 
            self.head = newnode
            return
        
        if not position:
            print("enter correct value")
            return
        
        currentnode = self.head
        prev = None
        
        while currentnode and position:
            prev = currentnode
            currentnode = currentnode.next
            position -= 1
        
        if position>0 or position<0:
            return print("Enter a valid value")
        
        newnode.next = current.next
        prev.next = newnode
        
    def prepend(self,data):
        newnode = Node(data)
        newnode.next = self.head
        self.head= newnode
        return
    
    def delete(self,key):
        currentnode = self.head
        if currentnode and currentnode.data == key:
            currentnode.next = self.head
            currentnode = None
            return
        prev = None
        while currentnode and currentnode.data != key:
            prev = currentnode
            currentnode =  currentnode.next
        if currentnode is None:
            print("key not found")
            return
        prev.next = currentnode.next
        currentnode = None
            
    def delete(self,post):
        try:
            currentnode = self.head
            if post == 0:
                self.head = currentnode.next
                currentnode = None
                return

            prev = None
            count = 1
            while currentnode and count != post:
                prev =currentnode
                currentnode = currentnode.next
                count +=1

            
            prev.next = currentnode.next
            currentnode = None
        except:
            if currentnode is None:
                return
    
    def __str__(self):
            currentnode = self.head
            while currentnode:
                x = currentnode.data
                print(f'{x}')
                currentnode = currentnode.next
        
    def __len__(self):
        currentnode = self.head
        count =  0
        while currentnode:
            count += 1
            currentnode = currentnode.next
        
        return count
    
    def lenrec(self,node):
        if node is None:
            return 0
        return 1 + self.lenrec(node.next)

    def swap(self,key_1,key_2):
        if key_1 == key_2:
            return
        
        prev1 = None
        currentnode1 = self.head
        while currentnode1 and currentnode1.data != key_1:
            prev1 = currentnode1
            currentnode1 = currentnode1.next
        
        prev2 = None
        currentnode2 = self.head
        while currentnode2 and currentnode2.data != key_2:
            prev2 = currentnode2
            currentnode2 = currentnode2.next
        
        if not currentnode1 and not currentnode2:
            return
        
        if prev1:
            prev1.next = currentnode2
        else:
            self.head = currentnode2
        
        if prev2:
            prev2.next = currentnode1
        else:
            self.head = currentnode1
            
        currentnode1.next, currentnode2.next = currentnode2.next,currentnode1.next
        
        
    def reverse(self):
        prev = None
        currentnode12 = self.head
        while currentnode12:
            nxt = currentnode12.next
            currentnode12.nxt = prev
            prev = currentnode12
            currentnode12 = nxt
            
        self.head = prev

# %%
k=linked_list()

# %%
k.append(7)
k.append(5)
k.append(4)
k.append(3)

# %%
print(k)
# Out:
# 7
# 5
# 4
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-eb2fa875d160> in <module>
# ----> 1 print(k)
#
# TypeError: __str__ returned non-string (type NoneType)

# %%
k.reverse()

# %%
k.printlist()
# Out:
# 3

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class linked_list:
    def __init__(self):
        self.head = None
        
    def append(self,data):
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            return
        lastnode = self.head
        while lastnode.next:
            lastnode = lastnode.next
        lastnode.next = newnode
      
        
    def printlist(self):
        currentnode = self.head
        while currentnode:
            print(currentnode.data)
            currentnode = currentnode.next
            
    def insert(self,position,data):
        newnode = Node(data)
        if position == 0:
            newnode.next = self.head 
            self.head = newnode
            return
        
        if not position:
            print("enter correct value")
            return
        
        currentnode = self.head
        prev = None
        
        while currentnode and position:
            prev = currentnode
            currentnode = currentnode.next
            position -= 1
        
        if position>0 or position<0:
            return print("Enter a valid value")
        
        newnode.next = current.next
        prev.next = newnode
        
    def prepend(self,data):
        newnode = Node(data)
        newnode.next = self.head
        self.head= newnode
        return
    
    def delete(self,key):
        currentnode = self.head
        if currentnode and currentnode.data == key:
            currentnode.next = self.head
            currentnode = None
            return
        prev = None
        while currentnode and currentnode.data != key:
            prev = currentnode
            currentnode =  currentnode.next
        if currentnode is None:
            print("key not found")
            return
        prev.next = currentnode.next
        currentnode = None
            
    def delete(self,post):
        try:
            currentnode = self.head
            if post == 0:
                self.head = currentnode.next
                currentnode = None
                return

            prev = None
            count = 1
            while currentnode and count != post:
                prev =currentnode
                currentnode = currentnode.next
                count +=1
            prev.next = currentnode.next
            currentnode = None
            
        except:
            if currentnode is None:
                return

    def __len__(self):
        currentnode = self.head
        count =  0
        while currentnode:
            count += 1
            currentnode = currentnode.next
        return count
    
    def lenrec(self,node):
        if node is None:
            return 0
        return 1 + self.lenrec(node.next)

    def swap(self,key_1,key_2):
        if key_1 == key_2:
            return
        
        prev1 = None
        currentnode1 = self.head
        while currentnode1 and currentnode1.data != key_1:
            prev1 = currentnode1
            currentnode1 = currentnode1.next
        
        prev2 = None
        currentnode2 = self.head
        while currentnode2 and currentnode2.data != key_2:
            prev2 = currentnode2
            currentnode2 = currentnode2.next
        
        if not currentnode1 and not currentnode2:
            return
        
        if prev1:
            prev1.next = currentnode2
        else:
            self.head = currentnode2
        
        if prev2:
            prev2.next = currentnode1
        else:
            self.head = currentnode1
            
        currentnode1.next,currentnode2.next = currentnode2.next,currentnode1.next
        
    def reverse(self):
        prev = None
        currentnode = self.head
        while currentnode:
            nxt = currentnode.next
            currentnode.next = prev
            prev = currentnode
            currentnode = nxt
        self.head = prev
        
    def rec_reverse(self):
        def rec_reverse(currentnode,prev):
            if not currentnode:
                return prev
            nxt = currentnode.next
            currentnode.next = prev
            prev = currentnode
            currentnode = nxt
            return rec_reverse(currentnode,prev)
        self.head = rec_reverse(currentnode=self.head,prev = None)
        
    def merged_sort(self,llist):
        p=self.head
        q=llist.head
        s =None
        if not p:
            return q
        if not q:
            return p
        if p and q:
            if p.data <= q.data:
                s = p
                p = s.next
            else:
                s = q
                q = s.next
            new_head = s
            
        while p and q:
            if p.data <= q.data:
                pass
            else:
                s.next = q
                s=q
                q=s.next
